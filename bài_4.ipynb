# %% [markdown]
# <a href="https://colab.research.google.com/github/TranTan1410/tuan12/blob/main/b%C3%A0i_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
kieuhinh=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_data=kieuhinh.flow_from_directory('/content/drive/MyDrive/btvn2/HINH_ANH1/train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 120 images belonging to 3 classes.

# %%
validation_data=kieuhinh.flow_from_directory('/content/drive/MyDrive/btvn2/HINH_ANH1/validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 44 images belonging to 3 classes.

# %%
training_data.class_indices
# Out:
# {'dat': 0, 'dung': 1, 'tan': 2}

# %%
model=Sequential()
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.3))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 128)               5308544
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 5,595,939
# Trainable params: 5,595,939
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])
history=model.fit(training_data,epochs=100,batch_size=64,verbose=1, validation_data=validation_data, callbacks=[EarlyStopping(monitor='val_loss', patience=20)])
# Out:
# Epoch 1/100
# 4/4 [==============================] - 46s 11s/step - loss: 10.4382 - accuracy: 0.3333 - val_loss: 1.0484 - val_accuracy: 0.3864
# Epoch 2/100
# 4/4 [==============================] - 1s 315ms/step - loss: 1.1020 - accuracy: 0.3917 - val_loss: 0.9650 - val_accuracy: 0.6136
# Epoch 3/100
# 4/4 [==============================] - 1s 322ms/step - loss: 0.9814 - accuracy: 0.5500 - val_loss: 0.8669 - val_accuracy: 0.8864
# Epoch 4/100
# 4/4 [==============================] - 1s 317ms/step - loss: 0.7286 - accuracy: 0.8583 - val_loss: 0.5499 - val_accuracy: 0.8409
# Epoch 5/100
# 4/4 [==============================] - 1s 324ms/step - loss: 0.4405 - accuracy: 0.8167 - val_loss: 0.1430 - val_accuracy: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 1s 325ms/step - loss: 0.2084 - accuracy: 0.9500 - val_loss: 0.0898 - val_accuracy: 0.9773
# Epoch 7/100
# 4/4 [==============================] - 1s 328ms/step - loss: 0.1406 - accuracy: 0.9417 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 8/100
# 4/4 [==============================] - 1s 325ms/step - loss: 0.1553 - accuracy: 0.9583 - val_loss: 0.0863 - val_accuracy: 0.9773
# Epoch 9/100
# 4/4 [==============================] - 1s 326ms/step - loss: 0.1714 - accuracy: 0.9417 - val_loss: 0.0523 - val_accuracy: 0.9773
# Epoch 10/100
# 4/4 [==============================] - 1s 322ms/step - loss: 0.0774 - accuracy: 0.9667 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 11/100
# 4/4 [==============================] - 1s 328ms/step - loss: 0.1836 - accuracy: 0.9250 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 12/100
# 4/4 [==============================] - 1s 319ms/step - loss: 0.6753 - accuracy: 0.8167 - val_loss: 0.0955 - val_accuracy: 1.0000
# Epoch 13/100
# 4/4 [==============================] - 1s 337ms/step - loss: 0.1764 - accuracy: 0.9667 - val_loss: 0.0619 - val_accuracy: 0.9545
# Epoch 14/100
# 4/4 [==============================] - 1s 321ms/step - loss: 0.1750 - accuracy: 0.9667 - val_loss: 0.0648 - val_accuracy: 0.9773
# Epoch 15/100
# 4/4 [==============================] - 1s 326ms/step - loss: 0.2735 - accuracy: 0.9583 - val_loss: 0.0692 - val_accuracy: 0.9773
# Epoch 16/100
# 4/4 [==============================] - 1s 328ms/step - loss: 0.1864 - accuracy: 0.9333 - val_loss: 0.0434 - val_accuracy: 1.0000
# Epoch 17/100
# 4/4 [==============================] - 1s 350ms/step - loss: 0.0880 - accuracy: 0.9917 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 18/100
# 4/4 [==============================] - 1s 325ms/step - loss: 0.0807 - accuracy: 0.9583 - val_loss: 0.0210 - val_accuracy: 0.9773
# Epoch 19/100
# 4/4 [==============================] - 1s 349ms/step - loss: 0.0633 - accuracy: 0.9667 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 20/100
# 4/4 [==============================] - 1s 349ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 21/100
# 4/4 [==============================] - 1s 322ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 7.1938e-04 - val_accuracy: 1.0000
# Epoch 22/100
# 4/4 [==============================] - 1s 348ms/step - loss: 0.0407 - accuracy: 0.9833 - val_loss: 4.3146e-04 - val_accuracy: 1.0000
# Epoch 23/100
# 4/4 [==============================] - 1s 322ms/step - loss: 0.0160 - accuracy: 0.9917 - val_loss: 2.1937e-04 - val_accuracy: 1.0000
# Epoch 24/100
# 4/4 [==============================] - 1s 325ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9773
# Epoch 25/100
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 8.1168e-05 - val_accuracy: 1.0000
# Epoch 26/100
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9773
# Epoch 27/100
# 4/4 [==============================] - 1s 354ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.4976e-05 - val_accuracy: 1.0000
# Epoch 28/100
# 4/4 [==============================] - 1s 313ms/step - loss: 0.0178 - accuracy: 0.9917 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 29/100
# 4/4 [==============================] - 1s 346ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 7.8786e-05 - val_accuracy: 1.0000
# Epoch 30/100
# 4/4 [==============================] - 1s 319ms/step - loss: 0.0135 - accuracy: 0.9917 - val_loss: 0.1921 - val_accuracy: 0.9318
# Epoch 31/100
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0926 - accuracy: 0.9917 - val_loss: 3.6630e-04 - val_accuracy: 1.0000
# Epoch 32/100
# 4/4 [==============================] - 1s 320ms/step - loss: 0.0603 - accuracy: 0.9750 - val_loss: 0.0499 - val_accuracy: 0.9773
# Epoch 33/100
# 4/4 [==============================] - 1s 318ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 34/100
# 4/4 [==============================] - 1s 325ms/step - loss: 0.0318 - accuracy: 0.9917 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 35/100
# 4/4 [==============================] - 1s 323ms/step - loss: 0.0503 - accuracy: 0.9750 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 36/100
# 4/4 [==============================] - 1s 326ms/step - loss: 0.0169 - accuracy: 0.9917 - val_loss: 3.7886e-04 - val_accuracy: 1.0000
# Epoch 37/100
# 4/4 [==============================] - 1s 354ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.2780e-04 - val_accuracy: 1.0000
# Epoch 38/100
# 4/4 [==============================] - 1s 317ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0797e-04 - val_accuracy: 1.0000
# Epoch 39/100
# 4/4 [==============================] - 1s 319ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.5446e-05 - val_accuracy: 1.0000
# Epoch 40/100
# 4/4 [==============================] - 1s 318ms/step - loss: 0.0235 - accuracy: 0.9917 - val_loss: 1.3996e-04 - val_accuracy: 1.0000
# Epoch 41/100
# 4/4 [==============================] - 1s 317ms/step - loss: 0.0351 - accuracy: 0.9917 - val_loss: 7.5654e-05 - val_accuracy: 1.0000
# Epoch 42/100
# 4/4 [==============================] - 1s 340ms/step - loss: 0.0155 - accuracy: 0.9917 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 43/100
# 4/4 [==============================] - 1s 328ms/step - loss: 0.0289 - accuracy: 0.9833 - val_loss: 1.6425e-04 - val_accuracy: 1.0000
# Epoch 44/100
# 4/4 [==============================] - 1s 321ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 7.0018e-04 - val_accuracy: 1.0000
# Epoch 45/100
# 4/4 [==============================] - 1s 326ms/step - loss: 0.0263 - accuracy: 0.9917 - val_loss: 0.0302 - val_accuracy: 0.9773
# Epoch 46/100
# 4/4 [==============================] - 1s 345ms/step - loss: 0.0358 - accuracy: 0.9833 - val_loss: 3.5908e-04 - val_accuracy: 1.0000
# Epoch 47/100
# 4/4 [==============================] - 1s 319ms/step - loss: 0.0232 - accuracy: 0.9917 - val_loss: 0.0123 - val_accuracy: 1.0000

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
model.save("Nhan_dien_nguoi.h5")
model_nhandien=load_model('Nhan_dien_nguoi.h5')
img=load_img("/content/drive/MyDrive/btvn2/HINH_ANH1/test/dat.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='dat'
if round(result[0][1])==1:
  prediction='dung'
if round(result[0][2])==1:
  prediction='Tan'
print(prediction)
# Out:
# dat

# %%
img=load_img("/content/drive/MyDrive/btvn2/HINH_ANH1/test/dung.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='dat'
if round(result[0][1])==1:
  prediction='dung'
if round(result[0][2])==1:
  prediction='Tan'
print(prediction)
# Out:
# dung

# %%
img=load_img("/content/drive/MyDrive/btvn2/HINH_ANH1/test/tan.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_nhandien.predict(img)
if round(result[0][0])==1:
  prediction='dat'
if round(result[0][1])==1:
  prediction='dung'
if round(result[0][2])==1:
  prediction='Tan'
print(prediction)
# Out:
# Tan
